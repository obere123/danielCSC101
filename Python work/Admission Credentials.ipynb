# %%
#This is a program to check applicant's credentials
name=input("What is your name?:   " )
jamb_score=int(input("What was your jamb score?:   " ))
if jamb_score>400 or jamb_score % 1 != 0:
    print("Not a valid Jamb score")
else:
    if jamb_score >=230:
        score= 0
        mathematics=input("What is your grade in mathematics?:      ")
        english=input("What Is your grade in English?:    ")
        physics=input("What is your grade in physics?:     ")
        chemistry=input("What is your grade in Chemistry?:    ")
        computer=input("What is your grade in Computer Studies?:   ")
        if mathematics=="A1" or mathematics=="B2" or mathematics=="B3" or mathematics=="C4" or mathematics=="C5" or mathematics=="C6":
               score += 1
        else:
               score += 0
        if english=="A1" or english=="B2" or english=="B3" or english=="C4" or english=="C5" or english=="C6":
               score += 1
        else:
               score += 0
        if physics=="A1" or physics=="B2" or physics=="B3" or physics=="C4" or physics=="C5" or physics=="C6":
               score += 1
        else:
               score += 0
        if chemistry=="A1" or chemistry=="B2" or chemistry=="B3" or chemistry=="C4" or chemistry=="C5" or chemistry=="C6":
               score += 1
        else:
               score += 0
        if computer=="A1" or computer=="B2" or computer=="B3" or computer=="C4" or computer=="C5" or computer=="C6":
               score += 1
        else:
               score +=0
        if score==5 :
               print("Congragulations, "+name+"!!You have been given admission")
        else:
               print("Sorry, you do not have admission")
    else:
        print ("Your jamb score is not high enough")
# Out:
# What is your name?:   Daniel
# What was your jamb score?:   320
# What is your grade in mathematics?:      A1
# What Is your grade in English?:    B2
# What is your grade in physics?:     B3
# What is your grade in Chemistry?:    C4
# What is your grade in Computer Studies?:   C5
# Congragulations, Daniel!!You have been given admission

# %%
def jamb():
    #This is a program to check applicant's credentials
    name=input("What is your name?:   " )
    jamb_score=int(input("What was your jamb score?:   " ))
    if jamb_score>400 or jamb_score % 1 != 0:
        print("Not a valid Jamb score")
    else:
        if jamb_score >=230:
            score= 0
            mathematics=input("What is your grade in mathematics?:      ")
            english=input("What Is your grade in English?:    ")
            physics=input("What is your grade in physics?:     ")
            chemistry=input("What is your grade in Chemistry?:    ")
            computer=input("What is your grade in Computer Studies?:   ")
            if mathematics=="A1" or mathematics=="B2" or mathematics=="B3" or mathematics=="C4" or mathematics=="C5" or mathematics=="C6":
                score += 1
            else:
                score += 0
            if english=="A1" or english=="B2" or english=="B3" or english=="C4" or english=="C5" or english=="C6":
                score += 1
            else:
                score += 0
            if physics=="A1" or physics=="B2" or physics=="B3" or physics=="C4" or physics=="C5" or physics=="C6":
                score += 1
            else:
                score += 0
            if chemistry=="A1" or chemistry=="B2" or chemistry=="B3" or chemistry=="C4" or chemistry=="C5" or chemistry=="C6":
                score += 1
            else:
                score += 0
            if computer=="A1" or computer=="B2" or computer=="B3" or computer=="C4" or computer=="C5" or computer=="C6":
                score += 1
            else:
                score +=0
            if score==5 :
                print("Congragulations, "+name+"!!You have been given admission")
            else:
                print("Sorry, you do not have admission")
        else:
            print ("Your jamb score is not high enough")
jamb()
# Out:
# What is your name?:   Daniel
# What was your jamb score?:   340
# What is your grade in mathematics?:      A1
# What Is your grade in English?:    B2
# What is your grade in physics?:     B3
# What is your grade in Chemistry?:    C6
# What is your grade in Computer Studies?:   A1
# Congragulations, Daniel!!You have been given admission
