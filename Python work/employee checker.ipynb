# %%
# This is a program to test for employees
employees=["Daniel Obere","Tabitha Udezi","Love Folami","David Jacobs","Timo Werner","Thomas Tuchel","Antonio Rudiger","Edouard Mendy","Kai Havertz","Christian Pulisic","Ngolo Kante","Reece James","Kepa Arrizabalaga","Jorginho Frello","Mason Mount"]
name=input("Please kindly enter your first and last name:     ")
if name in employees:
    print("Welcome, Please come in.")
else:
    print("You do not work here, please go away.")
# Out:
# Please kindly enter your first and last name:     Gina
# You do not work here, please go away.

# %%
def verify():
    # This is a program to test for employees
    employees=["Daniel Obere","Tabitha Udezi","Love Folami","David Jacobs","Timo Werner","Thomas Tuchel","Antonio Rudiger","Edouard Mendy","Kai Havertz","Christian Pulisic","Ngolo Kante","Reece James","Kepa Arrizabalaga","Jorginho Frello","Mason Mount"]
    name=input("Please kindly enter your first and last name:     ")
    if name in employees:
         print("Welcome, Please come in.")
    else:
        print("You do not work here, please go away.")
verify()
# Out:
# Please kindly enter your first and last name:     Daniel Obere
# Welcome, Please come in.
