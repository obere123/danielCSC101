# %%
def studentfunction():
    names={"Daniel Obere":99,"Tabitha Udezi":99,"Love Bolanle":99, "James Patrick":88, "Dejo Damilola":90,"Reece James":88,"Ajah Chinenye":99, "Romelu Lukaku":10,"Gina Briggs":99, "Bimpe Adetoba":97,"Ruth Obere":98,"Nelson Elijah":84,"Wale Agboola": 70,"Patrick Vierra": 68}
    name=input("Enter your name  to get your score")
    print(names[name])
studentfunction()
# Out:
# Enter your name  to get your scoreDaniel Obere
# 99
