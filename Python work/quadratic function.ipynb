# %%
import cmath
#Program to calculate roots of quadratic function
def quadratic(a,b,c):
    
    return (-b + ((b**2)-(4*a*c))**0.5)/(2*a), (-b - ((b**2)-(4*a*c))**0.5)/(2*a)
     
quadratic(1,-7,10)
# Out:
# (5.0, 2.0)

# %%
# Out:
# What is the radius:   7
# 43.982297150257104
