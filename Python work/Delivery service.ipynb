# %%
#Delivery Service program
print("Welcome to our delivery service")
location=input("Are you delivering to PAU or Epe?       ")
weight=float(input("What is the weight you desire in kilograms?   "))
if location=="PAU"or "Pau" or "Pan Atlantic University":
    if weight>=10:
        print("Your cost of delivery is N2000")
    else:
        print("Your cost of delivery is N1500")
elif location=="Epe" or location=="EPE":
    if weight>= 10:
        print("Your cost of delivery is N5000")
    else:
        print("Your cost of delivery is N4000")
else:
    print("We are not delivering to your location")
# Out:
# Welcome to our delivery service
# Are you delivering to PAU or Epe?       Epe
# What is the weight you desire in kilograms?   50
# Your cost of delivery is N2000

# %%
def delivery():
    #Delivery Service program
    print("Welcome to our delivery service")
    location=input("Are you delivering to PAU or Epe?       ")
    weight=float(input("What is the weight you desire in kilograms?   "))
    if location=="PAU"or "Pau" or "Pan Atlantic University":
        if weight>=10:
            print("Your cost of delivery is N2000")
        else:
            print("Your cost of delivery is N1500")
    elif location=="Epe" or location=="EPE":
        if weight>= 10:
             print("Your cost of delivery is N5000")
        else:
            print("Your cost of delivery is N4000")
    else:
            print("We are not delivering to your location")
delivery()
# Out:
# Welcome to our delivery service
# Are you delivering to PAU or Epe?       Pau
# What is the weight you desire in kilograms?   45
# Your cost of delivery is N2000
