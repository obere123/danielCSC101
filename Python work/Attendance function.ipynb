# %%
def ():
    list=("Daniel Obere", "Tabitha Udezi","Love Bolanle","Dejo Damilola","Reece James", "Thomas Tuchel", "Antonio Rudiger", "Timo Werner","Thoago Silva")
    name=input("What is the name of the student")
    if name in list:
        print("Present")
    else:
        print("Absent")
